# %%
import pandas as pd
df_claim=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")
df_claim
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df_claim.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df_claim.drop(columns=["_c39"],inplace=True)

# %%
df_claim.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        print(df_claim[col].value_counts())
        print()
# Out:
# 01-01-2006    3
# 05-08-1992    3
# 28-04-1992    3
# 21-12-2002    2
# 08-11-2009    2
#              ..
# 05-11-2000    1
# 23-04-1995    1
# 21-11-1991    1
# 04-01-1996    1
# 25-07-2011    1
# Name: policy_bind_date, Length: 951, dtype: int64
#
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
#
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64
#
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64
#
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64
#
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# exec-managerial      76
# sales                76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# ...

# %%
df_claim.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df_claim.drop(columns=["incident_date"],inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="incident_state",y="total_claim_amount",data=df_claim)
plt.show()

# %%
sns.countplot(x="collision_type",data=df_claim)
plt.show()

# %%
sns.countplot(x="authorities_contacted",data=df_claim)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="auto_make",data=df_claim)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="insured_occupation",y="total_claim_amount",data=df_claim)
plt.show()

# %%
df_claim.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
category_feat_list=list()
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        category_feat_list.append(col)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df_claim.columns:
    if df_claim[col].dtype=="object":
        df_claim[col]=LabelEncoder().fit_transform(df_claim[col])

# %%
df_x=df_claim.drop(columns=["total_claim_amount"])
y=df_claim[["total_claim_amount"]]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(df_x,y)
grid_search.best_params_

# %%
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
params={'learning_rate': 0.01,'max_depth': 25,'n_estimators': 200,'num_leaves': 300}
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train,categorical_feature=cate_feat_list)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2 score corresponding to ",r_state," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)

# %%
from sklearn.model_selection import KFold
import numpy as np
scores=[]
k_fold = KFold(n_splits=5)
for train_index,test_index in k_fold.split(df_x):
    x_train, x_test, y_train, y_test = df_x.iloc[train_index], df_x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_feat_list)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    scores.append(r2_scr)
print("Mean r2 score for lgbm regressor: ",np.array(scores).mean())
print("standard deviation in r2 score for lgbm regressor: ",np.array(scores).std())
print(scores)

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print("Cross Validation score",c_scores)

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.9873540376971162
# r2 score corresponding to  43  is  0.983190141944929
# r2 score corresponding to  44  is  0.9847746229326361
# r2 score corresponding to  45  is  0.9868322074905519
# r2 score corresponding to  46  is  0.9866113418013666
# r2 score corresponding to  47  is  0.9850502304589135
# r2 score corresponding to  48  is  0.9912482342069122
# r2 score corresponding to  49  is  0.9825613615200643
# r2 score corresponding to  50  is  0.9898717365439352
# r2 score corresponding to  51  is  0.988805571584705
# r2 score corresponding to  52  is  0.9838460339770816
# r2 score corresponding to  53  is  0.9887018825340733
# r2 score corresponding to  54  is  0.9882992745042067
# r2 score corresponding to  55  is  0.9778628334936682
# r2 score corresponding to  56  is  0.9841996927249059
# r2 score corresponding to  57  is  0.9852193750504924
# r2 score corresponding to  58  is  0.988335712477303
# ...

# %%
print("DECISION TREE\n\n")
model_evaluation(dtr,df_x,y)
# Out:
# DECISION TREE
#
#
# Mean r2 score for regressor:  0.9873089291461815
# standard deviation in r2 score for regressor:  0.001860190175364172
# Cross Validation score [0.98868186 0.98406908 0.98801748 0.98925688 0.98651934]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.9935212187567884
# r2 score corresponding to  43  is  0.9949914891772569
# r2 score corresponding to  44  is  0.9947299380749317
# r2 score corresponding to  45  is  0.9948592040826097
# r2 score corresponding to  46  is  0.994293372328876
# r2 score corresponding to  47  is  0.993826492642057
# r2 score corresponding to  48  is  0.9957020676969925
# r2 score corresponding to  49  is  0.994312365668163
# r2 score corresponding to  50  is  0.9949552486299904
# r2 score corresponding to  51  is  0.995865554575112
# r2 score corresponding to  52  is  0.9923233223109448
# r2 score corresponding to  53  is  0.9951225212993595
# r2 score corresponding to  54  is  0.993316516083671
# r2 score corresponding to  55  is  0.9925758527843991
# r2 score corresponding to  56  is  0.9955781583018181
# r2 score corresponding to  57  is  0.9959874338058085
# r2 score corresponding to  58  is  0.9952704084518951
# ...

# %%
print("RANDOM FORSET\n\n")
model_evaluation(rfr,df_x,y)
# Out:
# RANDOM FORSET
#
#
# Mean r2 score for regressor:  0.9950121709695109
# standard deviation in r2 score for regressor:  0.0006401300451288355
# Cross Validation score [0.99391427 0.99511528 0.99532027 0.99585657 0.99485447]
